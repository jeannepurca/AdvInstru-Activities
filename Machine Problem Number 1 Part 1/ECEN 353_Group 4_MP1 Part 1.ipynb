# %% [markdown]
# <table style="margin-left: 0; font-size: 15px;">
#     <tr>
#         <td style="padding-right:15px;">
#             <img src="PUPSTC LOGO.png" style="width:75px;height:75px;">
#         </td>
#         <td style="font-family: Arial; vertical-align:top;">
#             Republic of the Philippines<br />
#             <b>POLYTECHNIC UNIVERSITY OF THE PHILIPPINES</b><br />
#             <b>STO. TOMAS CAMPUS</b><br />
#             <b>BACHELOR OF SCIENCE IN ELECTRONICS ENGINEERING</b>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <center>Polytechnic University of The Philippines</center>
# <center>Sto. Tomas Campus</center>
# <center>Electronics Engineering Program</center>

# %% [markdown]
# <center>ECEN 353: Advanced Intrumentation & Control System</center>
# <center>Machine Problem Number 1 Part 1</center>
# <center>Second Semester SY 2024-2025 Activities: Group Number 4</center>

# %% [markdown]
# <b><center>Submitted by</center></b>
# <center>Hernandez, Daniella Kim Comendador</center>
# <center>Purca, Jeanne Mae Manic</center>
# <center>Roxas, April Talampas</center>

# %% [markdown]
# <b><center>Submitted To</center></b>
# <center>Dr. Robert G. de Luna, PECE</center>

# %% [markdown]
# <h2><b>Part 1: Data Wrangling<b></h2>

# %% [markdown]
# <div class="alert alert-info" role="alert">
# <b>Dataset Name:</b> <i>World Stock Prices ( Daily Updating )</i> <br>
# <b>Source:</b> <i>Kaggle</i> <br>
# <b>Kaggle Link:</b> https://www.kaggle.com/datasets/nelgiriyewithana/world-stock-prices-daily-updating?fbclid=IwZXh0bgNhZW0CMTEAAR4HZf1_ZHEcgmIwLI4mkG_Hkb-Tz1KnnWPSHqQxvQVfZZFny6qX6HNsoOKk6w_aem_n4OEpsyVH2c4QF-25HXHRg <br>
# </div>

# %% [markdown]
# <h3>Import the Libraries</h3>

# %%
# Import the Libraries (Pandas, Matplotlib, numpy)
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# <h3>Import and Display the Dataset</h3>

# %% [markdown]
# <div class="alert alert-info" role="alert">
# Use the Pandas method <b>read_csv()</b> to load the data. Then, use the method <b>head()</b> to display the first ten rows of the dataset.
# </div>

# %%
# Import the Dataset.
dataset = pd.read_csv("ECEN 353_MP1 Part 1_Original Dataset.csv")
dataset.head(10)
# Out:
#                         Date        Open        High         Low       Close  \
# 0  2025-04-22 00:00:00-04:00    5.410000    5.825000    5.380000    5.750000
# 1  2025-04-22 00:00:00-04:00   86.120003   87.169998   85.169998   86.260002
# 2  2025-04-22 00:00:00-04:00  115.760002  117.790001  115.529999  117.150002
# 3  2025-04-22 00:00:00-04:00  247.119995  253.240005  246.369995  252.419998
# 4  2025-04-22 00:00:00-04:00   22.200001   22.200001   22.200001   22.200001
# 5  2025-04-22 00:00:00-04:00  323.859985  332.559998  322.390015  331.399994
# 6  2025-04-22 00:00:00-04:00  349.140015  352.079987  344.369995  349.910004
# 7  2025-04-22 00:00:00-04:00   65.160004   65.660004   64.830002   65.430000
# 8  2025-04-22 00:00:00-04:00   55.220001   55.279999   54.590000   55.040001
# 9  2025-04-22 00:00:00-04:00  231.979996  235.990005  231.369995  235.589996
#
#        Volume  Dividends  Stock Splits           Brand_Name Ticker  \
# ...

# %% [markdown]
# <h3>Data Types</h3>

# %% [markdown]
# <div class="alert alert-info" role="alert">
# <p>Checking the data types of each variable ensures that the dataset is correctly formatted for analysis and modeling. This step helps catch inconsistencies or errors early in the data preprocessing pipeline.</p>
# <p>To check if the data types, we use the <b>.dtypes</b> method.</p>
# </div>

# %%
# Check the data type of the data frame.
dataset.dtypes
# Out:
# Date              object
# Open             float64
# High             float64
# Low              float64
# Close            float64
# Volume           float64
# Dividends        float64
# Stock Splits     float64
# Brand_Name        object
# Ticker            object
# Industry_Tag      object
# Country           object
# Capital Gains    float64
# dtype: object

# %% [markdown]
# <div class="alert alert-warning" role="alert">
# <p>By counterchecking the dataset, we confirmed that the data types assigned to each column are <b>correct</b> and match the kind of data they hold.</p>
# </div>

# %% [markdown]
# <h3>Summary of Data</h3>

# %% [markdown]
# <div class="alert alert-info" role="alert">
# <p>To get the statistical summary of each column, use the <b>.describe()</b> method. By using this function, the basic statistics for all continuous variables will be automatically computed. Any NaN values are automatically skipped in these statistics.</p>
# This will show:
# <ul>
#     <li>the count of that variable</li>
#     <li>the mean</li>
#     <li>the standard deviation (std)</li>
#     <li>the minimum value</li>
#     <li>the IQR (Interquartile Range: 25%, 50% and 75%)</li>
#     <li>the maximum value</li>
# </ul>
# </div>

# %%
# Describe all the columns.
dataset.describe(include = "all")
# Out:
#                              Date           Open           High  \
# count                      306775  306775.000000  306775.000000
# unique                       6362            NaN            NaN
# top     2024-08-16 00:00:00-04:00            NaN            NaN
# freq                          122            NaN            NaN
# mean                          NaN      75.106749      75.964188
# std                           NaN     140.063946     141.582075
# min                           NaN       0.196890       0.199922
# 25%                           NaN      15.827042      16.051048
# 50%                           NaN      35.053798      35.476027
# 75%                           NaN      82.269997      83.163363
# max                           NaN    3445.580078    3463.070068
#
#                   Low          Close        Volume      Dividends  \
# count   306775.000000  306775.000000  3.067750e+05  306775.000000
# ...

# %% [markdown]
# <div class="alert alert-info" role="alert">
# <p>To count the data and check the rows of data in each column, use the <b>.count()</b> method.</p>
# </div>

# %%
# Check the rows of data in each column
dataset_count = dataset.count()
dataset_count
# Out:
# Date             306775
# Open             306775
# High             306775
# Low              306775
# Close            306775
# Volume           306775
# Dividends        306775
# Stock Splits     306775
# Brand_Name       306775
# Ticker           306775
# Industry_Tag     306775
# Country          306775
# Capital Gains         2
# dtype: int64

# %% [markdown]
# <h3>Identify and Handle the Missing Values.</h3>

# %% [markdown]
# <div class="alert alert-info" role="alert">
# <h4>Identify Missing Values</h4>
# <p>Based on what was previously displayed, several <b>NaN</b> already appeared in the dataframe, which means there are missing values that may hinder the analysis. With this, the values must be corrected.</p>
# <p>To do this, use the <b>.replace(A, B, inplace=True)</b> method. Then, display it by applying the <b>.head()</b> function.</p>
# </div>

# %%
# Replace " " with NaN
dataset.replace(["", " "], np.nan, inplace=True)
dataset.head(10)
# Out:
#                         Date        Open        High         Low       Close  \
# 0  2025-04-22 00:00:00-04:00    5.410000    5.825000    5.380000    5.750000
# 1  2025-04-22 00:00:00-04:00   86.120003   87.169998   85.169998   86.260002
# 2  2025-04-22 00:00:00-04:00  115.760002  117.790001  115.529999  117.150002
# 3  2025-04-22 00:00:00-04:00  247.119995  253.240005  246.369995  252.419998
# 4  2025-04-22 00:00:00-04:00   22.200001   22.200001   22.200001   22.200001
# 5  2025-04-22 00:00:00-04:00  323.859985  332.559998  322.390015  331.399994
# 6  2025-04-22 00:00:00-04:00  349.140015  352.079987  344.369995  349.910004
# 7  2025-04-22 00:00:00-04:00   65.160004   65.660004   64.830002   65.430000
# 8  2025-04-22 00:00:00-04:00   55.220001   55.279999   54.590000   55.040001
# 9  2025-04-22 00:00:00-04:00  231.979996  235.990005  231.369995  235.589996
#
#        Volume  Dividends  Stock Splits           Brand_Name Ticker  \
# ...

# %% [markdown]
# <div class="alert alert-info" role="alert">
# <h4>Evaluating for Missing Data</h4>
# <p>The missing values are converted to Python's default.</p>
# <p>To detect missing data, the <b>.isnull()</b> function can be used, along with <b>.sum()</b> and <b>.sort.values()</b> to count the missing entries per column and sort the results from highest to lowest, so the column with the most missing values appears at the top.</p>
# </div>

# %%
# Check if there are missing data.
missing_data = dataset.isnull().sum().sort_values(ascending=False)
missing_data.head(10)
# Out:
# Capital Gains    306773
# Date                  0
# Open                  0
# High                  0
# Low                   0
# Close                 0
# Volume                0
# Dividends             0
# Stock Splits          0
# Brand_Name            0
# dtype: int64

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# Based on the summary above, each column has <b>306775 rows of data</b>, with <b>one column</b> containing missing data:
# <ol>
#     <li><b>Capital Gains:</b> 306773 missing data</li>
# </ol>
#
# This indicates that the entire column contains only 2 valid entries among all samples.
# </div>

# %% [markdown]
# <div class="alert alert-info" role="alert">
# <h4>Deal with Missing Data</h4>
# There are different ways to deal with missing data. This includes:
# <ol>
#     <li>drop data<br>
#         a. drop the whole row<br>
#         b. drop the whole column
#     </li>
#     <li>replace data<br>
#         a. replace it by mean<br>
#         b. replace it by frequency<br>
#         c. replace it based on other functions
#     </li>
# </ol>
# <p>Whole columns should be dropped only if most entries in the column are empty. In this dataset, <b><i>Capital Gains</i></b> column is empty enough to drop entirely.</p>
# <p>To do this, the <b>.drop()</b> function will be used.</p>
# </div>

# %%
dataset.drop('Capital Gains', axis=1, inplace=True)
dataset.head()
# Out:
#                         Date        Open        High         Low       Close  \
# 0  2025-04-22 00:00:00-04:00    5.410000    5.825000    5.380000    5.750000
# 1  2025-04-22 00:00:00-04:00   86.120003   87.169998   85.169998   86.260002
# 2  2025-04-22 00:00:00-04:00  115.760002  117.790001  115.529999  117.150002
# 3  2025-04-22 00:00:00-04:00  247.119995  253.240005  246.369995  252.419998
# 4  2025-04-22 00:00:00-04:00   22.200001   22.200001   22.200001   22.200001
#
#        Volume  Dividends  Stock Splits        Brand_Name Ticker Industry_Tag  \
# 0  10322800.0        0.0           0.0           peloton   PTON      fitness
# 1  35024900.0        0.0           0.0               amd    AMD   technology
# 2     51000.0        0.0           0.0            adidas  ADDYY      apparel
# 3   2321400.0        0.0           0.0  american express    AXP      finance
# 4         0.0        0.0           0.0              puma  PMMAF      apparel
#
#    Country
# 0      usa
# 1      usa
# ...

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# Now, it can be seen that the <b>Capital Gains</b> column has been <b>dropped</b> from the dataframe.
# </div>

# %% [markdown]
# <div class="alert alert-info" role="alert">
# <h3>Correct Data Format</h3>
# <p>The last step in data cleaning is checking and making sure that all data is in its correct format (int, float, text, etc.).</p>
# <p>Now, it can be seen that there is a column for dates, which also includes timezone information. Since we're working with stock data and aiming to predict the "Close" price, time is a crucial factor. However, the raw date string isn't directly useful in its current form.</p>
# <p>With this, the format of the <b>'Date'</b> column must be changed.</p>
# </div>

# %%
# Convert the "Date" column to a datetime format.
dataset['Date'] = pd.to_datetime(dataset['Date'], errors='coerce', utc=True)

# %%
# Extract useful features.
dataset['Year'] = dataset['Date'].dt.year
dataset['Month'] = dataset['Date'].dt.month
dataset['Day'] = dataset['Date'].dt.day
dataset['DayOfWeek'] = dataset['Date'].dt.dayofweek
dataset['IsWeekend'] = dataset['DayOfWeek'].apply(lambda x: 1 if x >= 5 else 0)
dataset['Days_Since_Start'] = (dataset['Date'] - dataset['Date'].min()).dt.days

# Drop the original Date column.
dataset.drop('Date', axis=1, inplace=True)

# Display the corrected dataframe.
dataset.head(40)
# Out:
#            Open         High          Low        Close      Volume  Dividends  \
# 0      5.410000     5.825000     5.380000     5.750000  10322800.0        0.0
# 1     86.120003    87.169998    85.169998    86.260002  35024900.0        0.0
# 2    115.760002   117.790001   115.529999   117.150002     51000.0        0.0
# 3    247.119995   253.240005   246.369995   252.419998   2321400.0        0.0
# 4     22.200001    22.200001    22.200001    22.200001         0.0        0.0
# 5    323.859985   332.559998   322.390015   331.399994   5428500.0        0.0
# 6    349.140015   352.079987   344.369995   349.910004   3248000.0        0.0
# 7     65.160004    65.660004    64.830002    65.430000   4099200.0        0.0
# 8     55.220001    55.279999    54.590000    55.040001  19949600.0        0.0
# 9    231.979996   235.990005   231.369995   235.589996  10692100.0        0.0
# 10   108.760002   112.150002   108.320000   111.400002    552100.0        0.0
# ...

# %% [markdown]
# <div class="alert alert-info" role="alert">
# Since several features were extracted from the <b>"Date"</b> column, it's important to recheck the dataset for any missing values that may have been introduced during the process.
# </div>

# %%
# Check the rows of data in each column
dataset_count = dataset.count()
dataset_count
# Out:
# Open                306775
# High                306775
# Low                 306775
# Close               306775
# Volume              306775
# Dividends           306775
# Stock Splits        306775
# Brand_Name          306775
# Ticker              306775
# Industry_Tag        306775
# Country             306775
# Year                306775
# Month               306775
# Day                 306775
# DayOfWeek           306775
# IsWeekend           306775
# Days_Since_Start    306775
# dtype: int64

# %% [markdown]
# <div class="alert alert-info" role="alert">
# The <b>"Close"</b> column will be the one predicted, it can be moved to the rightest side of the dataframe for the table to look more organized.
# </div>

# %%
# Move "Close" column to the end
target = dataset.pop('Close')  
dataset['Close'] = target     
dataset.head()
# Out:
#          Open        High         Low      Volume  Dividends  Stock Splits  \
# 0    5.410000    5.825000    5.380000  10322800.0        0.0           0.0
# 1   86.120003   87.169998   85.169998  35024900.0        0.0           0.0
# 2  115.760002  117.790001  115.529999     51000.0        0.0           0.0
# 3  247.119995  253.240005  246.369995   2321400.0        0.0           0.0
# 4   22.200001   22.200001   22.200001         0.0        0.0           0.0
#
#          Brand_Name Ticker Industry_Tag  Country  Year  Month  Day  DayOfWeek  \
# 0           peloton   PTON      fitness      usa  2025      4   22          1
# 1               amd    AMD   technology      usa  2025      4   22          1
# 2            adidas  ADDYY      apparel  germany  2025      4   22          1
# 3  american express    AXP      finance      usa  2025      4   22          1
# 4              puma  PMMAF      apparel  germany  2025      4   22          1
#
#    IsWeekend  Days_Since_Start       Close
# ...

# %% [markdown]
# <h3>Data Normalization</h3>

# %% [markdown]
# <div class="alert alert-info" role="alert">
# <p> <b>Normalization</b> is the process of transforming values of several variables into a similar range. Typical normalizations include scaling the variable so the variable average is 0, scaling the variable so the variance is 1, or scaling variable so the variable values range from 0 to 1.</p>
# </div>

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# <p>Normalize (Min-Max scaling): scales data to a [0, 1] range → good for features not normally distributed or bounded data (like percentages).</p>
#
# These are the information about the columns based on Kaggle:
# <ol>
#     <il>
#         <b>Date:</b> The date of the stock price data.<br>
#         <b>Open:</b> The opening price of the stock on that date.<br>
#         <b>High:</b> The highest price the stock reached during the trading day.<br>
#         <b>Low:</b> The lowest price the stock reached during the trading day.<br>
#         <b>Close:</b> The closing price of the stock on that date.<br>
#         <b>Volume:</b> The trading volume, i.e., the number of shares traded on that date.<br>
#         <b>Dividends:</b> Dividends paid on that date (if any).<br>
#         <b>Stock Splits:</b> Information about stock splits (if any).<br>
#         <b>Brand_Name:</b> The name of the brand or company.<br>
#         <b>Ticker:</b> Ticker symbol for the stock.<br>
#         <b>Industry_Tag:</b> The industry category or sector to which the brand belongs.<br>
#         <b>Country:</b> The country where the brand is headquartered or primarily operates.
#     </il>
# </ol>
# </div>

# %% [markdown]
# <div class="alert alert-info" role="alert">
# For this dataset, these are the columns <i>needed to be normalized</i>:
# <ol>
#     <il>
#         <b>1. Open</b><br>
#         <b>2. High</b><br>
#         <b>3. Low</b><br>
#         <b>4. Volume</b>
#     </il>
# </ol>
# </div>

# %%
from sklearn.preprocessing import MinMaxScaler, StandardScaler

# List the columns to normalize.
normalize_columns = ['Open', 'High', 'Low', 'Volume']

# Normalization of Columns
scaler_minmax = MinMaxScaler()
dataset[normalize_columns] = scaler_minmax.fit_transform(dataset[normalize_columns])
dataset.head()
# Out:
#        Open      High       Low    Volume  Dividends  Stock Splits  \
# 0  0.001513  0.001624  0.001539  0.001391        0.0           0.0
# 1  0.024939  0.025115  0.025217  0.004719        0.0           0.0
# 2  0.033541  0.033957  0.034227  0.000007        0.0           0.0
# 3  0.071668  0.073072  0.073054  0.000313        0.0           0.0
# 4  0.006386  0.006353  0.006531  0.000000        0.0           0.0
#
#          Brand_Name Ticker Industry_Tag  Country  Year  Month  Day  DayOfWeek  \
# 0           peloton   PTON      fitness      usa  2025      4   22          1
# 1               amd    AMD   technology      usa  2025      4   22          1
# 2            adidas  ADDYY      apparel  germany  2025      4   22          1
# 3  american express    AXP      finance      usa  2025      4   22          1
# 4              puma  PMMAF      apparel  germany  2025      4   22          1
#
#    IsWeekend  Days_Since_Start       Close
# 0          0              9240    5.750000
# ...

# %% [markdown]
# <h3>Indicator Variable (or Dummy Variable)</h3>

# %% [markdown]
# <div class="alert alert-info" role="alert">
# <p>An indicator variable (or dummy variable) is a numerical variable used to label categories. They are called 'dummies' because the numbers themselves don't have inherent meaning. These can be used to categorical variables for regression analysis in the later processes.
# <p>Now, the panda's method <b>"get_dummies"</b> will be used to assign numerical values to different categories of the following objects:</p>
# <ol>
#     <il>
#         <b>1. Brand_Name</b><br>
#         <b>2. Ticker</b><br>
#         <b>3. Industry_Tag</b><br>
#         <b>4. Country</b>
#     </il>
# </ol>
# </div>

# %%
dataset.select_dtypes(include='object').columns
# Out:
# Index(['Brand_Name', 'Ticker', 'Industry_Tag', 'Country'], dtype='object')

# %%
# Getting value counts of column "Brand Name"

dataset["Brand_Name"].value_counts()
# Out:
# Brand_Name
# marriott      6414
# nordstrom     6413
# mcdonald's    6413
# apple         6413
# amazon        6413
#               ...
# peloton       1449
# zoominfo      1276
# airbnb        1144
# roblox        1084
# coinbase      1060
# Name: count, Length: 61, dtype: int64

# %%
# Total number of uniqfie values

Brand_Name_unique_count = dataset['Brand_Name'].nunique()
print("Brand Name Unique Counts:", Brand_Name_unique_count)
# Out:
# Brand Name Unique Counts: 61

# %% [markdown]
# <div class="alert alert-info" role="alert">
# A concern surfaces as having to have an additional off 61 columns seems inefficient. Let's take a look at the unique value counts of other columns.
# </div>

# %%
Ticker_unique_count = dataset['Ticker'].nunique()
print("Ticker Unique Counts:", Ticker_unique_count)
# Out:
# Ticker Unique Counts: 61

# %%
Industry_Tag_unique_count = dataset['Industry_Tag'].nunique()
print("Industry_Tag Unique Counts:", Industry_Tag_unique_count)
# Out:
# Industry_Tag Unique Counts: 23

# %%
Country_unique_count = dataset['Country'].nunique()
print("Country Unique Counts:", Country_unique_count)
# Out:
# Country Unique Counts: 7

# %% [markdown]
# <div class="alert alert-info" role="alert">
# <p> All in all, there will be an additional <b>152 columns</b>. Instead of making dummy variables, we can use target encoding.</p>
# <b>Target encoding</b> is any kind of encoding that replaces a feature's categories with some number derived from the target.
# </div>

# %%
# Target Encoding
brand_avg = dataset.groupby("Brand_Name")["Close"].mean()
dataset["Brand_Name_encoded"] = dataset["Brand_Name"].map(brand_avg)
dataset.head()
# Out:
#        Open      High       Low    Volume  Dividends  Stock Splits  \
# 0  0.001513  0.001624  0.001539  0.001391        0.0           0.0
# 1  0.024939  0.025115  0.025217  0.004719        0.0           0.0
# 2  0.033541  0.033957  0.034227  0.000007        0.0           0.0
# 3  0.071668  0.073072  0.073054  0.000313        0.0           0.0
# 4  0.006386  0.006353  0.006531  0.000000        0.0           0.0
#
#          Brand_Name Ticker Industry_Tag  Country  Year  Month  Day  DayOfWeek  \
# 0           peloton   PTON      fitness      usa  2025      4   22          1
# 1               amd    AMD   technology      usa  2025      4   22          1
# 2            adidas  ADDYY      apparel  germany  2025      4   22          1
# 3  american express    AXP      finance      usa  2025      4   22          1
# 4              puma  PMMAF      apparel  germany  2025      4   22          1
#
#    IsWeekend  Days_Since_Start       Close  Brand_Name_encoded
# ...

# %%
# Target Encoding
ticker_avg = dataset.groupby("Ticker")["Close"].mean()
dataset["Ticker_encoded"] = dataset["Ticker"].map(ticker_avg)
dataset.head()
# Out:
#        Open      High       Low    Volume  Dividends  Stock Splits  \
# 0  0.001513  0.001624  0.001539  0.001391        0.0           0.0
# 1  0.024939  0.025115  0.025217  0.004719        0.0           0.0
# 2  0.033541  0.033957  0.034227  0.000007        0.0           0.0
# 3  0.071668  0.073072  0.073054  0.000313        0.0           0.0
# 4  0.006386  0.006353  0.006531  0.000000        0.0           0.0
#
#          Brand_Name Ticker Industry_Tag  Country  Year  Month  Day  DayOfWeek  \
# 0           peloton   PTON      fitness      usa  2025      4   22          1
# 1               amd    AMD   technology      usa  2025      4   22          1
# 2            adidas  ADDYY      apparel  germany  2025      4   22          1
# 3  american express    AXP      finance      usa  2025      4   22          1
# 4              puma  PMMAF      apparel  germany  2025      4   22          1
#
#    IsWeekend  Days_Since_Start       Close  Brand_Name_encoded  Ticker_encoded
# ...

# %%
# Target Encoding
industry_avg = dataset.groupby("Industry_Tag")["Close"].mean()
dataset["Industry_Tag_encoded"] = dataset["Industry_Tag"].map(industry_avg)
dataset.head()
# Out:
#        Open      High       Low    Volume  Dividends  Stock Splits  \
# 0  0.001513  0.001624  0.001539  0.001391        0.0           0.0
# 1  0.024939  0.025115  0.025217  0.004719        0.0           0.0
# 2  0.033541  0.033957  0.034227  0.000007        0.0           0.0
# 3  0.071668  0.073072  0.073054  0.000313        0.0           0.0
# 4  0.006386  0.006353  0.006531  0.000000        0.0           0.0
#
#          Brand_Name Ticker Industry_Tag  Country  Year  Month  Day  DayOfWeek  \
# 0           peloton   PTON      fitness      usa  2025      4   22          1
# 1               amd    AMD   technology      usa  2025      4   22          1
# 2            adidas  ADDYY      apparel  germany  2025      4   22          1
# 3  american express    AXP      finance      usa  2025      4   22          1
# 4              puma  PMMAF      apparel  germany  2025      4   22          1
#
#    IsWeekend  Days_Since_Start       Close  Brand_Name_encoded  \
# ...

# %%
# Target Encoding
country_avg = dataset.groupby("Country")["Close"].mean()
dataset["Country_encoded"] = dataset["Country"].map(country_avg)
dataset.head()
# Out:
#        Open      High       Low    Volume  Dividends  Stock Splits  \
# 0  0.001513  0.001624  0.001539  0.001391        0.0           0.0
# 1  0.024939  0.025115  0.025217  0.004719        0.0           0.0
# 2  0.033541  0.033957  0.034227  0.000007        0.0           0.0
# 3  0.071668  0.073072  0.073054  0.000313        0.0           0.0
# 4  0.006386  0.006353  0.006531  0.000000        0.0           0.0
#
#          Brand_Name Ticker Industry_Tag  Country  ...  Month  Day  DayOfWeek  \
# 0           peloton   PTON      fitness      usa  ...      4   22          1
# 1               amd    AMD   technology      usa  ...      4   22          1
# 2            adidas  ADDYY      apparel  germany  ...      4   22          1
# 3  american express    AXP      finance      usa  ...      4   22          1
# 4              puma  PMMAF      apparel  germany  ...      4   22          1
#
#    IsWeekend  Days_Since_Start       Close  Brand_Name_encoded  \
# ...

# %% [markdown]
# <div class="alert alert-info" role="alert">
# <p>After cleaning the dataset, it can now be saved into another csv file.</p>
# </div>

# %%
dataset.to_csv("(Cleaned) ECEN 353_MP1 Part 1_World-Stock-Prices-Dataset.csv", index=False)

# %% [markdown]
# <h2><b>Part 2: Exploratory Data Analysis<b></h2>

# %% [markdown]
# <h3>Import the Cleaned Dataset.</h3>

# %%
# Import and display the Cleaned Dataset.
clean_dataset = pd.read_csv("(Cleaned) ECEN 353_MP1 Part 1_World-Stock-Prices-Dataset.csv")
clean_dataset.head(10)
# Out:
#        Open      High       Low    Volume  Dividends  Stock Splits  \
# 0  0.001513  0.001624  0.001539  0.001391        0.0           0.0
# 1  0.024939  0.025115  0.025217  0.004719        0.0           0.0
# 2  0.033541  0.033957  0.034227  0.000007        0.0           0.0
# 3  0.071668  0.073072  0.073054  0.000313        0.0           0.0
# 4  0.006386  0.006353  0.006531  0.000000        0.0           0.0
# 5  0.093941  0.095978  0.095613  0.000731        0.0           0.0
# 6  0.101278  0.101615  0.102136  0.000438        0.0           0.0
# 7  0.018855  0.018903  0.019181  0.000552        0.0           0.0
# 8  0.015970  0.015906  0.016143  0.002688        0.0           0.0
# 9  0.067274  0.068091  0.068602  0.001441        0.0           0.0
#
#             Brand_Name Ticker    Industry_Tag      Country  ...  Month  Day  \
# 0              peloton   PTON         fitness          usa  ...      4   22
# ...

# %% [markdown]
# <h3> Analyzing Individual Feature Patterns using Visualization</h3>

# %% [markdown]
# <div class="alert alert-info" role="alert">
# To install seaborn, we use the pip which is the Python package manager.
# </div>

# %%
# %%capture
! pip install seaborn

# %% [markdown]
# <div class="alert alert-info" role="alert">
#  Import visualization packages <b>"Seaborn"</b>, and do not forget about <b>"%matplotlib inline"</b> to plot in a Jupyter notebook.
# </div>

# %%
# Import the Seaborn library, and integrate the %matplotlib inline
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# <div class="alert alert-info" role="alert">
# Since a new cleaned dataset was imported, the data types must first be checked to ensure that there will be no conflicts along the process.
# </div>

# %%
# List the data types for each column.
clean_dataset.dtypes
# Out:
# Open                    float64
# High                    float64
# Low                     float64
# Volume                  float64
# Dividends               float64
# Stock Splits            float64
# Brand_Name               object
# Ticker                   object
# Industry_Tag             object
# Country                  object
# Year                      int64
# Month                     int64
# Day                       int64
# DayOfWeek                 int64
# IsWeekend                 int64
# Days_Since_Start          int64
# Close                   float64
# Brand_Name_encoded      float64
# Ticker_encoded          float64
# Industry_Tag_encoded    float64
# Country_encoded         float64
# dtype: object

# %%
# Determine the correlation between the variables.
clean_dataset.corr(numeric_only=True)
# Out:
#                           Open      High       Low    Volume  Dividends  \
# Open                  1.000000  0.999918  0.999882 -0.073368   0.019192
# High                  0.999918  1.000000  0.999842 -0.073042   0.019061
# Low                   0.999882  0.999842  1.000000 -0.073763   0.019310
# Volume               -0.073368 -0.073042 -0.073763  1.000000  -0.009262
# Dividends             0.019192  0.019061  0.019310 -0.009262   1.000000
# Stock Splits          0.000476  0.000512 -0.000623  0.003780  -0.000365
# Year                  0.380047  0.380376  0.379823 -0.095476   0.023833
# Month                -0.000393 -0.000662 -0.000099 -0.012377  -0.000284
# Day                   0.000237  0.000123  0.000399  0.000375   0.001179
# DayOfWeek             0.009097  0.009054  0.009091  0.004489   0.009993
# IsWeekend                  NaN       NaN       NaN       NaN        NaN
# Days_Since_Start      0.380156  0.380475  0.379945 -0.095994   0.023834
# ...

# %% [markdown]
# <h4>Continuous Numerical Variables</h4>

# %% [markdown]
# <div class="alert alert-info" role="alert">
# <p>These are the variables that may contain any value within some range, and can have the type "int64" or "float64".</p>
# <p>To visualize these variables, we will be using scatterplots with fitted lines to understand the (linear) relationship between an individual variable and the price. This will be done by using <b>"regplot"</b>, which plots the scatterplot plus the fitted regression line for the data.</p>
# </div>

# %%
clean_dataset.select_dtypes(include=['int','float']).columns
# Out:
# Index(['Open', 'High', 'Low', 'Volume', 'Dividends', 'Stock Splits', 'Year',
#        'Month', 'Day', 'DayOfWeek', 'IsWeekend', 'Days_Since_Start', 'Close',
#        'Brand_Name_encoded', 'Ticker_encoded', 'Industry_Tag_encoded',
#        'Country_encoded'],
#       dtype='object')

# %%
fig, axes = plt.subplots(2, 3, figsize=(18, 10))

# Plot the variable "Open" as a potential predictor variable of "Close".
sns.regplot(x="Open", y="Close", data=clean_dataset, ax=axes[0, 0])
axes[0, 0].set_ylim(0,)
axes[0, 0].set_title("Open vs Close")

# Plot the variable "High" as a potential predictor variable of "Close".
sns.regplot(x="High", y="Close", data=clean_dataset, ax=axes[0, 1])
axes[0, 1].set_ylim(0,)
axes[0, 1].set_title("High vs Close")

# Plot the variable "Low" as a potential predictor variable of "Close".
sns.regplot(x="Low", y="Close", data=clean_dataset, ax=axes[0, 2])
axes[0, 2].set_ylim(0,)
axes[0, 2].set_title("Low vs Close")

# Plot the variable "Volume" as a potential predictor variable of "Close".
sns.regplot(x="Volume", y="Close", data=clean_dataset, ax=axes[1, 0])
axes[1, 0].set_ylim(0,)
axes[1, 0].set_title("Volume vs Close")

# Plot the variable "Dividends" as a potential predictor variable of "Close".
sns.regplot(x="Dividends", y="Close", data=clean_dataset, ax=axes[1, 1])
axes[1, 1].set_ylim(0,)
axes[1, 1].set_title("Dividends vs Close")

# Plot the variable "Stock Splits" as a potential predictor variable of "Close".
sns.regplot(x="Stock Splits", y="Close", data=clean_dataset, ax=axes[1, 2])
axes[1, 2].set_ylim(0,)
axes[1, 2].set_title("Stock Splits vs Close")

plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="alert alert-warning" role="alert">
# <b>Conclusion:</b> <i>Since the numerical columns "Volume", "Dividends" and "Stock Splits" do not project a linear relationship based on the generated boxplot, these features cannot be considered as predictors of "Close". Only the features "Open", "High", and "Low" can be used as predictors.</i>
# </div>

# %%
fig, axes = plt.subplots(2, 3, figsize=(18, 10))

# Plot the variable "Year" as a potential predictor variable of "Close".
sns.regplot(x="Year", y="Close", data=clean_dataset, ax=axes[0, 0])
axes[0, 0].set_ylim(0,)
axes[0, 0].set_title("Year vs Close")

# Plot the variable "Month" as a potential predictor variable of "Close".
sns.regplot(x="Month", y="Close", data=clean_dataset, ax=axes[0, 1])
axes[0, 1].set_ylim(0,)
axes[0, 1].set_title("Month vs Close")

# Plot the variable "Day" as a potential predictor variable of "Close".
sns.regplot(x="Day", y="Close", data=clean_dataset, ax=axes[0, 2])
axes[0, 2].set_ylim(0,)
axes[0, 2].set_title("Day vs Close")

# Plot the variable "DayOfWeek" as a potential predictor variable of "Close".
sns.regplot(x="DayOfWeek", y="Close", data=clean_dataset, ax=axes[1, 0])
axes[1, 0].set_ylim(0,)
axes[1, 0].set_title("DayOfWeek vs Close")

# Plot the variable "IsWeekend" as a potential predictor variable of "Close".
sns.regplot(x="IsWeekend", y="Close", data=clean_dataset, ax=axes[1, 1])
axes[1, 1].set_ylim(0,)
axes[1, 1].set_title("IsWeekend vs Close")

# Plot the variable "Days_Since_Start" as a potential predictor variable of "Close".
sns.regplot(x="Days_Since_Start", y="Close", data=clean_dataset, ax=axes[1, 2])
axes[1, 2].set_ylim(0,)
axes[1, 2].set_title("Days_Since_Start vs Close")

plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# <b>Conclusion:</b> <i>Since these numerical columns ("Year", "Month", "Day", "DayOfWeek", "IsWeekend", and "Days_Since_Start") do not project a linear relationship based on the generated boxplot, these features cannot be considered as predictors of "Close".
# </div>

# %%
fig, axes = plt.subplots(2, 2, figsize=(18, 10))

# Plot the variable "Brand_Name_encoded" as a potential predictor variable of "Close".
sns.regplot(x="Brand_Name_encoded", y="Close", data=clean_dataset, ax=axes[0, 0])
axes[0, 0].set_ylim(0,)
axes[0, 0].set_title("Brand_Name_encoded vs Close")

# Plot the variable "Ticker_encoded" as a potential predictor variable of "Close".
sns.regplot(x="Ticker_encoded", y="Close", data=clean_dataset, ax=axes[0, 1])
axes[0, 1].set_ylim(0,)
axes[0, 1].set_title("Ticker_encoded vs Close")

# Plot the variable "Industry_Tag_encoded" as a potential predictor variable of "Close".
sns.regplot(x="Industry_Tag_encoded", y="Close", data=clean_dataset, ax=axes[1, 0])
axes[1, 0].set_ylim(0,)
axes[1, 0].set_title("Industry_Tag_encoded vs Close")

# Plot the variable "Country_encoded" as a potential predictor variable of "Close".
sns.regplot(x="Country_encoded", y="Close", data=clean_dataset, ax=axes[1, 1])
axes[1, 1].set_ylim(0,)
axes[1, 1].set_title("Country_encoded vs Close")

plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="alert alert-danger" role="alert">
# <b>Conclusion:</b> <i>Since the categorical columns ("Brand_Name_encoded", "Ticker_encoded", "Industry_Tag_encoded", "Country_encoded") do not project a linear relationship based on the generated boxplot, these features cannot be considered as predictors of "Close".</i>
# </div>

# %% [markdown]
# <h4>Categorical Variables</h4>

# %% [markdown]
# <div class="alert alert-info" role="alert">
# <p>These are the variables that describe a 'characteristic' of a data unit, and are selected from a small group of categories. They can have the type "object" or "int64".</p>
# <p>To visualize these variables, we will be using <b>"boxplot"</b>.</p>
# </div>

# %%
fig, axes = plt.subplots(2, 2, figsize=(18, 10))

# Plot the variable "Brand_Name_encoded" as a potential predictor variable of "Close".
sns.boxplot(x="Brand_Name", y="Close", data=clean_dataset, ax=axes[0, 0])
axes[0, 0].set_ylim(0,)
axes[0, 0].set_title("Brand_Name vs Close")

# Plot the variable "Ticker_encoded" as a potential predictor variable of "Close".
sns.boxplot(x="Ticker", y="Close", data=clean_dataset, ax=axes[0, 1])
axes[0, 1].set_ylim(0,)
axes[0, 1].set_title("Ticker vs Close")

# Plot the variable "Industry_Tag_encoded" as a potential predictor variable of "Close".
sns.boxplot(x="Industry_Tag", y="Close", data=clean_dataset, ax=axes[1, 0])
axes[1, 0].set_ylim(0,)
axes[1, 0].set_title("Industry_Tag vs Close")

# Plot the variable "Country_encoded" as a potential predictor variable of "Close".
sns.boxplot(x="Country", y="Close", data=clean_dataset, ax=axes[1, 1])
axes[1, 1].set_ylim(0,)
axes[1, 1].set_title("Country vs Close")

plt.tight_layout()
plt.show()

# %% [markdown]
# <div class="alert alert-danger alertdanger">
# <b>Conclusion:</b> <i>Since the categorical columns ("Brand_Name", "Ticker", "Industry_Tag", "Country") do not project a linear relationship based on the generated boxplot, these features cannot be considered as predictors of "Close".</i>
# </div>

# %% [markdown]
# <h3>Correlation and Causation</h3>

# %% [markdown]
# <div class="alert alert-info" role="alert">
# <p><b>Correlation</b>: a measure of the extent of interdependence between variables.<br>
# <b>Causation</b>: the relationship between cause and effect between two variables.</p>
#
# <p>Determining correlation is much simpler than determining causation as causation may require independent experimentation.</p>
# </div

# %% [markdown]
# <div class="alert alert-info" role="alert">
# <h4>Pearson Correlation</h4>
# <p>The Pearson Correlation measures the linear dependence between two variables X and Y.</p>
# <p>The resulting coefficient is a value between -1 and 1 inclusive, where:</p>
# <ul>
#     <li><b>1</b>: Total positive linear correlation.</li>
#     <li><b>0</b>: No linear correlation, the two variables most likely do not affect each other.</li>
#     <li><b>-1</b>: Total negative linear correlation.</li>
# </ul>
# <p>Pearson Correlation is the default method of the function "corr".  Like before we can calculate the Pearson Correlation of the of the 'int64' or 'float64'  variables.</p>
#     </div>

# %%
# To generate the Pearson Correlations Coefficient between variables
clean_dataset.corr
# Out:
# <bound method DataFrame.corr of             Open      High       Low    Volume  Dividends  Stock Splits  \
# 0       0.001513  0.001624  0.001539  0.001391        0.0           0.0
# 1       0.024939  0.025115  0.025217  0.004719        0.0           0.0
# 2       0.033541  0.033957  0.034227  0.000007        0.0           0.0
# 3       0.071668  0.073072  0.073054  0.000313        0.0           0.0
# 4       0.006386  0.006353  0.006531  0.000000        0.0           0.0
# ...          ...       ...       ...       ...        ...           ...
# 306770  0.002745  0.002762  0.002719  0.000442        0.0           0.0
# 306771  0.006658  0.006670  0.006618  0.000387        0.0           0.0
# 306772  0.010525  0.010583  0.010266  0.007172        0.0           0.0
# 306773  0.004287  0.004445  0.004301  0.001057        0.0           0.0
# 306774  0.001606  0.001615  0.001554  0.000785        0.0           0.0
#
# ...

# %% [markdown]
# <div class="alert alert-info" role="alert">
# Sometimes we would like to know the significant of the correlation estimate.
# </div>

# %% [markdown]
# <div class="alert alert-info" role="alert">
# <h4>P-value</h4>
# <p>The P-value is the probability value that the correlation between these two variables is statistically significant. Normally, we choose a significance level of 0.05, which means that we are 95% confident that the correlation between the variables is significant.</p>
#
# By convention, when
# <ul>
#     <li>the p-value is $<$ 0.001: we say there is strong evidence that the correlation is significant.</li>
#     <li>the p-value is $<$ 0.05: there is moderate evidence that the correlation is significant.</li>
#     <li>the p-value is $<$ 0.1: there is weak evidence that the correlation is significant.</li>
#     <li>the p-value is $>$ 0.1: there is no evidence that the correlation is significant.</li>
# </ul>
#     </div>

# %% [markdown]
# <div class="alert alert-info" role="alert">
# We can obtain this information using  <b>"stats"</b> module in the <b>"scipy"</b>  library.
# </div>

# %%
# To import Stats Library from Scipy
from scipy import stats

# %% [markdown]
# <div class="alert alert-info" role="alert">
# Let us calculate the <b>Pearson Correlation Coefficient</b> and <b>P-value</b> of the variables:
# </div>

# %%
# To calculate the Pearson Correlation Coefficient and the P-Value between "Open" and "Close".
r, p = stats.pearsonr(clean_dataset["Open"], clean_dataset["Close"])

# To display the results
print("The Pearson Coefficient of Correlation is", r, "with a p-value of", p)
# Out:
# The Pearson Coefficient of Correlation is 0.999810210001349 with a p-value of 0.0

# %% [markdown]
# <div class="alert alert-warning" role="alert">
# <b>Conclusion:</b> <i>Since the p-value is $<$ 0.001, the correlation between "Open" and "Close" is statistically significant, and the linear relationship is extremely strong (~0.999, can be rounded off to 1)</i></p>
# </div>

# %%
# To calculate the Pearson Correlation Coefficient and the P-Value between "High" and "Close".
r, p = stats.pearsonr(clean_dataset["High"], clean_dataset["Close"])

# To display the results
print("The Pearson Coefficient of Correlation is", r, "with a p-value of", p)
# Out:
# The Pearson Coefficient of Correlation is 0.9998937619276153 with a p-value of 0.0

# %% [markdown]
# <div class="alert alert-warning" role="alert">
# <b>Conclusion:</b> <i>Since the p-value is $<$ 0.001, the correlation between "High" and "Close" is statistically significant, and the linear relationship is extremely strong (~0.999, can be rounded off to 1)</i></p>
# </div>

# %%
# To calculate the Pearson Correlation Coefficient and the P-Value between "Low" and "Close".
r, p = stats.pearsonr(clean_dataset["Low"], clean_dataset["Close"])

# To display the results
print("The Pearson Coefficient of Correlation is", r, "with a p-value of", p)
# Out:
# The Pearson Coefficient of Correlation is 0.999918052375296 with a p-value of 0.0

# %% [markdown]
# <div class="alert alert-warning" role="alert">
# <b>Conclusion:</b> <i>Since the p-value is $<$ 0.001, the correlation between "Low" and "Close" is statistically significant, and the linear relationship is extremely strong (~0.999, can be rounded off to 1)</i></p>
# </div>

# %% [markdown]
# <div class="alert alert-success" role="alert">
# <h3>Conclusion: Important Variables</h3>
# <p>From the process that was done, we have narrowed down the predictors to the following variables:</p>
#
# <b>Continuous numerical variables:</b>
# <ul>
#     <li>Open</li>
#     <li>High</li>
#     <li>Low</li>
# </ul>
#
# <b>Categorical variables:</b> <i>None</i>
# <p>As we now move into building machine learning models to automate our analysis, feeding the model with variables that meaningfully affect our target variable will improve our model's prediction performance.</p>
# </div>

# %% [markdown]
# <div class="alert alert-info" role="alert">
# <p>After performing Data Wrangling and Exploratory Data Analysis, it can now be saved into another csv file.</p>
# </div>

# %%
dataset.to_csv("ECEN 353_Group 4_MP1 Part1_DW and EDA.csv", index=False)

# %% [markdown]
# <center>Bonifacio St., Matandang Balara, Sto. Tomas, 4234 Batangas</center>
# <center>Phone: (043) 778 3586 | Website: www.pup.edu.ph</center>
# <center style="font-family: Times New Roman" >“THE COUNTRY’S 1ST POLYTECHNIC U”</center>
