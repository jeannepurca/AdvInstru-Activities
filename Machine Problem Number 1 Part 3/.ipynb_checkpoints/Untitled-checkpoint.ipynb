# %% [markdown]
# <td style="font-family: Arial; vertical-align:top;">
#     Republic of the Philippines<br />
#     <b>POLYTECHNIC UNIVERSITY OF THE PHILIPPINES</b><br />
#     <b>STO. TOMAS CAMPUS</b><br />
#     <b>BACHELOR OF SCIENCE IN ELECTRONICS ENGINEERING</b>
# </td>

# %% [markdown]
# <center>Polytechnic University of The Philippines</center>
# <center>Sto. Tomas Campus</center>
# <center>Electronics Engineering Program</center><br>
# <center> <center>
# <center>ECEN 353: Advanced Intrumentation & Control System</center>
# <center>Machine Problem Number 1 Part 1</center>
# <center>Second Semester SY 2024-2025 Activities: Group Number 4</center><br>
# <center> <center>
# <b><center>Submitted by</center></b>
# <center>Hernandez, Daniella Kim Comendador</center>
# <center>Purca, Jeanne Mae Manic</center>
# <center>Roxas, April Talampas</center><br>
# <center> <center>
# <b><center>Submitted To</center></b>
# <center>Dr. Robert G. de Luna, PECE</center>

# %% [markdown]
# <h3>Import the Libraries</h3>

# %%
# Import the Libraries (Pandas, Matplotlib, numpy)
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# <h3>Import and Display the Dataset</h3>

# %% [markdown]
# <div class="alert alert-info" role="alert">
# Use the Pandas method <b>read_csv()</b> to load the data.
# </div>

# %%
# Import the Dataset.
dataset = pd.read_csv("(Cleaned) World-Stock-Prices-Dataset.csv")
dataset.head(10)
# Out:
#        Open      High       Low    Volume  Dividends  Stock Splits  \
# 0  0.001513  0.001624  0.001539  0.001391        0.0           0.0
# 1  0.024939  0.025115  0.025217  0.004719        0.0           0.0
# 2  0.033541  0.033957  0.034227  0.000007        0.0           0.0
# 3  0.071668  0.073072  0.073054  0.000313        0.0           0.0
# 4  0.006386  0.006353  0.006531  0.000000        0.0           0.0
# 5  0.093941  0.095978  0.095613  0.000731        0.0           0.0
# 6  0.101278  0.101615  0.102136  0.000438        0.0           0.0
# 7  0.018855  0.018903  0.019181  0.000552        0.0           0.0
# 8  0.015970  0.015906  0.016143  0.002688        0.0           0.0
# 9  0.067274  0.068091  0.068602  0.001441        0.0           0.0
#
#             Brand_Name Ticker    Industry_Tag      Country  ...  Month  Day  \
# 0              peloton   PTON         fitness          usa  ...      4   22
# ...

# %%
Preliminary Analysis of the Dataset

# %%
# A. To check if there is a missing data
missing_data = dataset.isnull().sum().sort_values(ascending=False)
missing_data
# Out:
# Open                    0
# Month                   0
# Industry_Tag_encoded    0
# Ticker_encoded          0
# Brand_Name_encoded      0
# Close                   0
# Days_Since_Start        0
# IsWeekend               0
# DayOfWeek               0
# Day                     0
# Year                    0
# High                    0
# Country                 0
# Industry_Tag            0
# Ticker                  0
# Brand_Name              0
# Stock Splits            0
# Dividends               0
# Volume                  0
# Low                     0
# Country_encoded         0
# dtype: int64

# %%
# B. To check column names and the total records
dataset_count = dataset.count()
dataset_count
# Out:
# Open                    306775
# High                    306775
# Low                     306775
# Volume                  306775
# Dividends               306775
# Stock Splits            306775
# Brand_Name              306775
# Ticker                  306775
# Industry_Tag            306775
# Country                 306775
# Year                    306775
# Month                   306775
# Day                     306775
# DayOfWeek               306775
# IsWeekend               306775
# Days_Since_Start        306775
# Close                   306775
# Brand_Name_encoded      306775
# Ticker_encoded          306775
# Industry_Tag_encoded    306775
# Country_encoded         306775
# dtype: int64

# %%
# C. To view inforrmation about the dataset
print(dataset.info())

# %%
# D. To view the statistical summary of the dataset
statistics = dataset.describe()
statistics
# Out:
#                 Open           High            Low         Volume  \
# count  306775.000000  306775.000000  306775.000000  306775.000000
# mean        0.021742       0.021879       0.021970       0.003072
# std         0.040653       0.040886       0.041086       0.011594
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.004537       0.004577       0.004576       0.000185
# 50%         0.010117       0.010187       0.010222       0.000618
# 75%         0.023821       0.023958       0.024102       0.001635
# max         1.000000       1.000000       1.000000       1.000000
#
#            Dividends   Stock Splits           Year          Month  \
# count  306775.000000  306775.000000  306775.000000  306775.000000
# mean        0.003619       0.000884    2013.616070       6.508096
# std         0.069742       0.116062       7.198667       3.441801
# min         0.000000       0.000000    2000.000000       1.000000
# ...

# %%
# Move "Close" column to the end
target = dataset.pop('Close')  
dataset['Close'] = target     
dataset.head()
# Out:
#        Open      High       Low    Volume  Dividends  Stock Splits  \
# 0  0.001513  0.001624  0.001539  0.001391        0.0           0.0
# 1  0.024939  0.025115  0.025217  0.004719        0.0           0.0
# 2  0.033541  0.033957  0.034227  0.000007        0.0           0.0
# 3  0.071668  0.073072  0.073054  0.000313        0.0           0.0
# 4  0.006386  0.006353  0.006531  0.000000        0.0           0.0
#
#          Brand_Name Ticker Industry_Tag  Country  ...  Month  Day  DayOfWeek  \
# 0           peloton   PTON      fitness      usa  ...      4   22          1
# 1               amd    AMD   technology      usa  ...      4   22          1
# 2            adidas  ADDYY      apparel  germany  ...      4   22          1
# 3  american express    AXP      finance      usa  ...      4   22          1
# 4              puma  PMMAF      apparel  germany  ...      4   22          1
#
#    IsWeekend  Days_Since_Start  Brand_Name_encoded  Ticker_encoded  \
# ...

# %%
# To Create a Matrix of Independent Variable, X
X = dataset.iloc[:, 0:20].values
# X_df = pd.DataFrame(X, columns=dataset.columns[0:20])
X_df.head()
# Out:
#        Open      High       Low    Volume Dividends Stock Splits  \
# 0  0.001513  0.001624  0.001539  0.001391       0.0          0.0
# 1  0.024939  0.025115  0.025217  0.004719       0.0          0.0
# 2  0.033541  0.033957  0.034227  0.000007       0.0          0.0
# 3  0.071668  0.073072  0.073054  0.000313       0.0          0.0
# 4  0.006386  0.006353  0.006531       0.0       0.0          0.0
#
#          Brand_Name Ticker Industry_Tag  Country  Year Month Day DayOfWeek  \
# 0           peloton   PTON      fitness      usa  2025     4  22         1
# 1               amd    AMD   technology      usa  2025     4  22         1
# 2            adidas  ADDYY      apparel  germany  2025     4  22         1
# 3  american express    AXP      finance      usa  2025     4  22         1
# 4              puma  PMMAF      apparel  germany  2025     4  22         1
#
#   IsWeekend Days_Since_Start Brand_Name_encoded Ticker_encoded  \
# ...

# %%
# To Create a Matrix of Dependent Variable, Y
Y = dataset.iloc[:, 20:].values
#Y_df = pd.DataFrame(Y, columns=dataset.columns[20:])
Y_df.head()
# Out:
#         Close
# 0    5.750000
# 1   86.260002
# 2  117.150002
# 3  252.419998
# 4   22.200001

# %% [markdown]
# A. Perform Backward Elimination Process to identify set of features to be used in machine learning models.

# %%
import statsmodels.regression.linear_model as lm
